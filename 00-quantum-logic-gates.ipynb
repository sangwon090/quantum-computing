# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit_aer import AerSimulator

# %%
# Pauli Gates

qc = QuantumCircuit(3)
qc.x(0)
qc.y(1)
qc.z(2)

qc_s = Statevector.from_instruction(qc)
qc_m = qc.measure_all()

sim = AerSimulator()
job = sim.run(qc, shots=1024)
res = job.result()

qc.draw(output='mpl')

# %%
plot_histogram(res.get_counts())

# %%
plot_bloch_multivector(qc_s)

# %%
# Hadamard gate

qc = QuantumCircuit(1)
qc.h(0)

qc_s = Statevector.from_instruction(qc)
qc_m = qc.measure_all()

sim = AerSimulator()
job = sim.run(qc, shots=1024)
res = job.result()

qc.draw(output='mpl')

# %%
plot_histogram(res.get_counts())

# %%
plot_bloch_multivector(qc_s)
